# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# AI-SEE Equity Analysis\n",
    "\n",
    "This notebook demonstrates basic analysis for the AI-SEE prioritization engine."
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "import pandas as pd\n",
    "import matplotlib.pyplot as plt"
   ],
   "execution_count": null,
   "outputs": []
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Load Data"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "worldpop = pd.read_csv('../data/worldpop_grids.csv')\n",
    "osm = pd.read_csv('../data/osm_services.csv')\n",
    "display(worldpop.head())\n",
    "display(osm.head())"
   ],
   "execution_count": null,
   "outputs": []
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Population Distribution"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "plt.hist(worldpop['population'], bins=5)\n",
    "plt.title('Population per Grid Cell')\n",
    "plt.xlabel('Population')\n",
    "plt.ylabel('Count')\n",
    "plt.show()"
   ],
   "execution_count": null,
   "outputs": []
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Service Counts by Type"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "osm['type'].value_counts().plot(kind='bar')\n",
    "plt.title('Service Counts by Type')\n",
    "plt.xlabel('Service Type')\n",
    "plt.ylabel('Count')\n",
    "plt.show()"
   ],
   "execution_count": null,
   "outputs": []
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.8"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 2
}
